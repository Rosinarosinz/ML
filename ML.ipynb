# %% [markdown]
# # Player Re-ldentification in  Sports Footage

# %% [markdown]
# #### Re-Identification in a Single Feed

# %%
import numpy as np
import torch
import torchvision.transforms as transforms
from ultralytics import YOLO
import os
import json
from datetime import datetime
from collections import defaultdict, deque
import logging
from PIL import Image, ImageDraw, ImageFont
import imageio
from scipy.spatial.distance import cdist
import math

# Setup logging
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class FeatureExtractor:
    def __init__(self):
        self.transform = transforms.Compose([
            transforms.Resize((128, 64)),
            transforms.ToTensor(),
            transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
        ])

    def rgb_to_hsv(self, rgb_array):
        rgb_array = rgb_array.astype(np.float32) / 255.0
        r, g, b = rgb_array[:,:,0], rgb_array[:,:,1], rgb_array[:,:,2]
        max_val = np.maximum(np.maximum(r, g), b)
        min_val = np.minimum(np.minimum(r, g), b)
        diff = max_val - min_val
        h = np.zeros_like(max_val)
        mask = diff != 0
        r_mask = (max_val == r) & mask
        g_mask = (max_val == g) & mask
        b_mask = (max_val == b) & mask
        h[r_mask] = (60 * ((g[r_mask] - b[r_mask]) / diff[r_mask]) + 360) % 360
        h[g_mask] = (60 * ((b[g_mask] - r[g_mask]) / diff[g_mask]) + 120) % 360
        h[b_mask] = (60 * ((r[b_mask] - g[b_mask]) / diff[b_mask]) + 240) % 360
        s = np.zeros_like(max_val)
        s[max_val != 0] = diff[max_val != 0] / max_val[max_val != 0]
        v = max_val
        h = (h / 360 * 179).astype(np.uint8)
        s = (s * 255).astype(np.uint8)
        v = (v * 255).astype(np.uint8)
        return np.stack([h, s, v], axis=2)

    def calculate_histogram(self, channel, bins, range_vals):
        hist, _ = np.histogram(channel.flatten(), bins=bins, range=range_vals)
        if hist.sum() > 0:
            hist = hist.astype(np.float32) / hist.sum()
        return hist

    def extract_histogram_features(self, image_crop):
        if image_crop.size == 0:
            return np.zeros(671)
        hsv = self.rgb_to_hsv(image_crop)
        hist_h = self.calculate_histogram(hsv[:,:,0], 180, (0, 180))
        hist_s = self.calculate_histogram(hsv[:,:,1], 256, (0, 256))
        hist_v = self.calculate_histogram(hsv[:,:,2], 256, (0, 256))
        return np.concatenate([hist_h, hist_s, hist_v])

    def extract_lbp_features(self, image_crop):
        if image_crop.size == 0:
            return np.zeros(256)
        if len(image_crop.shape) == 3:
            gray = np.dot(image_crop[...,:3], [0.2989, 0.5870, 0.1140])
        else:
            gray = image_crop
        gray = gray.astype(np.uint8)
        rows, cols = gray.shape
        lbp = np.zeros_like(gray)
        for i in range(1, rows-1):
            for j in range(1, cols-1):
                center = gray[i, j]
                code = 0
                code |= (gray[i-1, j-1] > center) << 7
                code |= (gray[i-1, j] > center) << 6
                code |= (gray[i-1, j+1] > center) << 5
                code |= (gray[i, j+1] > center) << 4
                code |= (gray[i+1, j+1] > center) << 3
                code |= (gray[i+1, j] > center) << 2
                code |= (gray[i+1, j-1] > center) << 1
                code |= (gray[i, j-1] > center)
                lbp[i, j] = code
        return self.calculate_histogram(lbp, 256, (0, 256))

    def extract_features(self, image_crop):
        if image_crop.size == 0:
            return np.zeros(927)
        try:
            h, w = image_crop.shape[:2]
            if h < 32 or w < 16:
                pil_img = Image.fromarray(image_crop)
                pil_img = pil_img.resize((32, 64))
                image_crop = np.array(pil_img)
            hist_features = self.extract_histogram_features(image_crop)
            lbp_features = self.extract_lbp_features(image_crop)
            return np.concatenate([hist_features, lbp_features])
        except Exception as e:
            logger.warning(f"Feature extraction failed: {e}")
            return np.zeros(927)

class PlayerTracker:
    def __init__(self, max_disappeared=30, max_distance=100):
        self.next_id = 0
        self.players = {}
        self.disappeared = {}
        self.max_disappeared = max_disappeared
        self.max_distance = max_distance
        self.feature_extractor = FeatureExtractor()

    def register_player(self, centroid, bbox, features):
        self.players[self.next_id] = {
            'centroid': centroid,
            'bbox': bbox,
            'features': features,
            'history': deque([centroid], maxlen=10)
        }
        self.disappeared[self.next_id] = 0
        self.next_id += 1
        return self.next_id - 1

    def deregister_player(self, player_id):
        del self.players[player_id]
        del self.disappeared[player_id]

    def calculate_distance(self, point1, point2):
        return math.sqrt((point1[0] - point2[0]) ** 2 + (point1[1] - point2[1]) ** 2)

    def calculate_feature_similarity(self, f1, f2):
        if np.linalg.norm(f1) == 0 or np.linalg.norm(f2) == 0:
            return 0
        return np.dot(f1, f2) / (np.linalg.norm(f1) * np.linalg.norm(f2))

    def update(self, detections, frame):
        if len(detections) == 0:
            for pid in list(self.disappeared.keys()):
                self.disappeared[pid] += 1
                if self.disappeared[pid] > self.max_disappeared:
                    self.deregister_player(pid)
            return {}
        input_centroids = []
        input_features = []
        for (x1, y1, x2, y2, conf, cls) in detections:
            if cls == 0:
                centroid = (int((x1 + x2) / 2), int((y1 + y2) / 2))
                input_centroids.append(centroid)
                crop = frame[int(y1):int(y2), int(x1):int(x2)]
                features = self.feature_extractor.extract_features(crop)
                input_features.append(features)
        if len(self.players) == 0:
            for i, (centroid, features) in enumerate(zip(input_centroids, input_features)):
                bbox = detections[i][:4]
                self.register_player(centroid, bbox, features)
        else:
            player_ids = list(self.players.keys())
            D = np.zeros((len(input_centroids), len(player_ids)))
            for i, (c, f) in enumerate(zip(input_centroids, input_features)):
                for j, pid in enumerate(player_ids):
                    dist = self.calculate_distance(c, self.players[pid]['centroid'])
                    sim = self.calculate_feature_similarity(f, self.players[pid]['features'])
                    D[i][j] = dist * (1 - sim + 0.1)
            used_row_idxs, used_col_idxs = set(), set()
            for _ in range(min(len(input_centroids), len(player_ids))):
                (r, c) = np.unravel_index(np.argmin(D), D.shape)
                if D[r, c] > self.max_distance:
                    break
                if r in used_row_idxs or c in used_col_idxs:
                    D[r, c] = np.inf
                    continue
                pid = player_ids[c]
                self.players[pid]['centroid'] = input_centroids[r]
                self.players[pid]['bbox'] = detections[r][:4]
                self.players[pid]['features'] = input_features[r]
                self.players[pid]['history'].append(input_centroids[r])
                self.disappeared[pid] = 0
                used_row_idxs.add(r)
                used_col_idxs.add(c)
                D[r, c] = np.inf
            for r in set(range(len(input_centroids))) - used_row_idxs:
                self.register_player(input_centroids[r], detections[r][:4], input_features[r])
            for c in set(range(len(player_ids))) - used_col_idxs:
                pid = player_ids[c]
                self.disappeared[pid] += 1
                if self.disappeared[pid] > self.max_disappeared:
                    self.deregister_player(pid)
        return self.players

class PlayerReIdentification:
    def __init__(self, model_path="yolov8n.pt"):
        self.model_path = model_path
        self.model = None
        self.tracker = PlayerTracker()
        self.frame_count = 0
        self.results_log = []

    def load_model(self):
        try:
            if os.path.exists(self.model_path):
                self.model = YOLO(self.model_path)
                logger.info(f"Model loaded from {self.model_path}")
            else:
                logger.warning(f"Model file not found: {self.model_path}")
                self.model = YOLO("yolov8n.pt")
        except Exception as e:
            logger.error(f"Model loading failed: {e}")
            self.model = YOLO("yolov8n.pt")

    def detect_players(self, frame):
        if self.model is None:
            return []
        try:
            results = self.model(frame, verbose=False)
            detections = []
            for result in results:
                for box in result.boxes:
                    x1, y1, x2, y2 = box.xyxy[0].cpu().numpy()
                    conf = box.conf[0].cpu().numpy()
                    cls = int(box.cls[0].cpu().numpy())
                    if cls == 0 and conf > 0.5:
                        detections.append([x1, y1, x2, y2, conf, cls])
            return detections
        except Exception as e:
            logger.error(f"Detection failed: {e}")
            return []

    def draw_results(self, frame, players):
        result_frame = Image.fromarray(frame)
        draw = ImageDraw.Draw(result_frame)
        try:
            font = ImageFont.truetype("arial.ttf", 20)
        except:
            font = ImageFont.load_default()
        for pid, info in players.items():
            x1, y1, x2, y2 = info['bbox']
            c = info['centroid']
            draw.rectangle([int(x1), int(y1), int(x2), int(y2)], outline="green", width=2)
            draw.text((int(x1), int(y1) - 20), f"Player {pid}", fill="yellow", font=font)
            draw.ellipse([c[0]-4, c[1]-4, c[0]+4, c[1]+4], fill="red")
        return np.array(result_frame)

    def process_video(self, video_path, output_path=None, display=False):
        if not os.path.exists(video_path):
            logger.error(f"Video file not found: {video_path}")
            return
        self.load_model()
        reader = imageio.get_reader(video_path)
        fps = reader.get_meta_data().get('fps', 30)
        writer = imageio.get_writer(output_path, fps=fps) if output_path else None

        for frame_idx, frame in enumerate(reader):
            self.frame_count += 1
            detections = self.detect_players(frame)
            players = self.tracker.update(detections, frame)

            # ✅ Log player positions for each frame
            frame_data = {
                "frame": self.frame_count,
                "players": {
                    pid: {
                        "centroid": info["centroid"],
                        "bbox": [float(x) for x in info["bbox"]]
                    } for pid, info in players.items()
                }
            }
            self.results_log.append(frame_data)

            result_frame = self.draw_results(frame, players)
            if writer:
                writer.append_data(result_frame)

            logger.info(f"Processed Frame {self.frame_count}")

        if writer:
            writer.close()
        reader.close()
        self.save_results()

    def save_results(self, filename=None):
        if filename is None:
            filename = f"tracking_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
        with open(filename, 'w') as f:
            json.dump(self.results_log, f, indent=2)
        logger.info(f"Saved tracking results to {filename}")


# --- Run script ---
if __name__ == "__main__":
    video_path = r"C:\\Users\\KASIM\\Downloads\\15sec_input_720p (1).mp4"
    model_path = "C:\\Users\\KASIM\\Downloads\\best (1).pt"
    output_path ="C:\\Users\\KASIM\\Downloads\\Op\\output_video.mp4"
    display_results = False

    system = PlayerReIdentification(model_path=model_path)
    system.process_video(video_path, output_path, display=display_results)
# Out:
# INFO:__main__:Model loaded from C:\Users\KASIM\Downloads\best (1).pt
# INFO:__main__:Processed Frame 1
# INFO:__main__:Processed Frame 2
# INFO:__main__:Processed Frame 3
# INFO:__main__:Processed Frame 4
# INFO:__main__:Processed Frame 5
# INFO:__main__:Processed Frame 6
# INFO:__main__:Processed Frame 7
# INFO:__main__:Processed Frame 8
# INFO:__main__:Processed Frame 9
# INFO:__main__:Processed Frame 10
# INFO:__main__:Processed Frame 11
# INFO:__main__:Processed Frame 12
# INFO:__main__:Processed Frame 13
# INFO:__main__:Processed Frame 14
# INFO:__main__:Processed Frame 15
# INFO:__main__:Processed Frame 16
# INFO:__main__:Processed Frame 17
# INFO:__main__:Processed Frame 18
# INFO:__main__:Processed Frame 19
# INFO:__main__:Processed Frame 20
# INFO:__main__:Processed Frame 21
# INFO:__main__:Processed Frame 22
# INFO:__main__:Processed Frame 23
# INFO:__main__:Processed Frame 24
# INFO:__main__:Processed Frame 25
# INFO:__main__:Processed Frame 26
# INFO:__main__:Processed Frame 27
# INFO:__main__:Processed Frame 28
# INFO:__main__:Processed Frame 29
# INFO:__main__:Processed Frame 30
# INFO:__main__:Processed Frame 31
# INFO:__main__:Processed Frame 32
# INFO:__main__:Processed Frame 33
# INFO:__main__:Processed Frame 34
# INFO:__main__:Processed Frame 35
# INFO:__main__:Processed Frame 36
# INFO:__main__:Processed Frame 37
# INFO:__main__:Processed Frame 38
# INFO:__main__:Processed Frame 39
# INFO:__main__:Processed Frame 40
# INFO:__main__:Processed Frame 41
# INFO:__main__:Processed Frame 42
# INFO:__main__:Processed Frame 43
# INFO:__main__:Processed Frame 44
# INFO:__main__:Processed Frame 45
# INFO:__main__:Processed Frame 46
# INFO:__main__:Processed Frame 47
# INFO:__main__:Processed Frame 48
# INFO:__main__:Processed Frame 49
# INFO:__main__:Processed Frame 50
# INFO:__main__:Processed Frame 51
# INFO:__main__:Processed Frame 52
# INFO:__main__:Processed Frame 53
# INFO:__main__:Processed Frame 54
# INFO:__main__:Processed Frame 55
# INFO:__main__:Processed Frame 56
# INFO:__main__:Processed Frame 57
# INFO:__main__:Processed Frame 58
# INFO:__main__:Processed Frame 59
# INFO:__main__:Processed Frame 60
# INFO:__main__:Processed Frame 61
# INFO:__main__:Processed Frame 62
# INFO:__main__:Processed Frame 63
# INFO:__main__:Processed Frame 64
# INFO:__main__:Processed Frame 65
# INFO:__main__:Processed Frame 66
# INFO:__main__:Processed Frame 67
# INFO:__main__:Processed Frame 68
# INFO:__main__:Processed Frame 69
# INFO:__main__:Processed Frame 70
# INFO:__main__:Processed Frame 71
# INFO:__main__:Processed Frame 72
# INFO:__main__:Processed Frame 73
# INFO:__main__:Processed Frame 74
# INFO:__main__:Processed Frame 75
# INFO:__main__:Processed Frame 76
# INFO:__main__:Processed Frame 77
# INFO:__main__:Processed Frame 78
# INFO:__main__:Processed Frame 79
# INFO:__main__:Processed Frame 80
# INFO:__main__:Processed Frame 81
# INFO:__main__:Processed Frame 82
# INFO:__main__:Processed Frame 83
# INFO:__main__:Processed Frame 84
# INFO:__main__:Processed Frame 85
# INFO:__main__:Processed Frame 86
# INFO:__main__:Processed Frame 87
# INFO:__main__:Processed Frame 88
# INFO:__main__:Processed Frame 89
# INFO:__main__:Processed Frame 90
# INFO:__main__:Processed Frame 91
# INFO:__main__:Processed Frame 92
# INFO:__main__:Processed Frame 93
# INFO:__main__:Processed Frame 94
# INFO:__main__:Processed Frame 95
# INFO:__main__:Processed Frame 96
# INFO:__main__:Processed Frame 97
# INFO:__main__:Processed Frame 98
# INFO:__main__:Processed Frame 99
# INFO:__main__:Processed Frame 100
# INFO:__main__:Processed Frame 101
# INFO:__main__:Processed Frame 102
# INFO:__main__:Processed Frame 103
# INFO:__main__:Processed Frame 104
# INFO:__main__:Processed Frame 105
# INFO:__main__:Processed Frame 106
# INFO:__main__:Processed Frame 107
# INFO:__main__:Processed Frame 108
# INFO:__main__:Processed Frame 109
# INFO:__main__:Processed Frame 110
# INFO:__main__:Processed Frame 111
# INFO:__main__:Processed Frame 112
# INFO:__main__:Processed Frame 113
# INFO:__main__:Processed Frame 114
# INFO:__main__:Processed Frame 115
# INFO:__main__:Processed Frame 116
# INFO:__main__:Processed Frame 117
# INFO:__main__:Processed Frame 118
# INFO:__main__:Processed Frame 119
# INFO:__main__:Processed Frame 120
# INFO:__main__:Processed Frame 121
# INFO:__main__:Processed Frame 122
# INFO:__main__:Processed Frame 123
# INFO:__main__:Processed Frame 124
# INFO:__main__:Processed Frame 125
# INFO:__main__:Processed Frame 126
# INFO:__main__:Processed Frame 127
# INFO:__main__:Processed Frame 128
# INFO:__main__:Processed Frame 129
# INFO:__main__:Processed Frame 130
# INFO:__main__:Processed Frame 131
# INFO:__main__:Processed Frame 132
# INFO:__main__:Processed Frame 133
# INFO:__main__:Processed Frame 134
# INFO:__main__:Processed Frame 135
# INFO:__main__:Processed Frame 136
# INFO:__main__:Processed Frame 137
# INFO:__main__:Processed Frame 138
# INFO:__main__:Processed Frame 139
# INFO:__main__:Processed Frame 140
# INFO:__main__:Processed Frame 141
# INFO:__main__:Processed Frame 142
# INFO:__main__:Processed Frame 143
# INFO:__main__:Processed Frame 144
# INFO:__main__:Processed Frame 145
# INFO:__main__:Processed Frame 146
# INFO:__main__:Processed Frame 147
# INFO:__main__:Processed Frame 148
# INFO:__main__:Processed Frame 149
# INFO:__main__:Processed Frame 150
# INFO:__main__:Processed Frame 151
# INFO:__main__:Processed Frame 152
# INFO:__main__:Processed Frame 153
# INFO:__main__:Processed Frame 154
# INFO:__main__:Processed Frame 155
# INFO:__main__:Processed Frame 156
# INFO:__main__:Processed Frame 157
# INFO:__main__:Processed Frame 158
# INFO:__main__:Processed Frame 159
# INFO:__main__:Processed Frame 160
# INFO:__main__:Processed Frame 161
# INFO:__main__:Processed Frame 162
# INFO:__main__:Processed Frame 163
# INFO:__main__:Processed Frame 164
# INFO:__main__:Processed Frame 165
# INFO:__main__:Processed Frame 166
# INFO:__main__:Processed Frame 167
# INFO:__main__:Processed Frame 168
# INFO:__main__:Processed Frame 169
# INFO:__main__:Processed Frame 170
# INFO:__main__:Processed Frame 171
# INFO:__main__:Processed Frame 172
# INFO:__main__:Processed Frame 173
# INFO:__main__:Processed Frame 174
# INFO:__main__:Processed Frame 175
# INFO:__main__:Processed Frame 176
# INFO:__main__:Processed Frame 177
# INFO:__main__:Processed Frame 178
# INFO:__main__:Processed Frame 179
# INFO:__main__:Processed Frame 180
# INFO:__main__:Processed Frame 181
# INFO:__main__:Processed Frame 182
# INFO:__main__:Processed Frame 183
# INFO:__main__:Processed Frame 184
# INFO:__main__:Processed Frame 185
# INFO:__main__:Processed Frame 186
# INFO:__main__:Processed Frame 187
# INFO:__main__:Processed Frame 188
# INFO:__main__:Processed Frame 189
# INFO:__main__:Processed Frame 190
# INFO:__main__:Processed Frame 191
# INFO:__main__:Processed Frame 192
# INFO:__main__:Processed Frame 193
# INFO:__main__:Processed Frame 194
# INFO:__main__:Processed Frame 195
# INFO:__main__:Processed Frame 196
# INFO:__main__:Processed Frame 197
# INFO:__main__:Processed Frame 198
# INFO:__main__:Processed Frame 199
# INFO:__main__:Processed Frame 200
# INFO:__main__:Processed Frame 201
# INFO:__main__:Processed Frame 202
# INFO:__main__:Processed Frame 203
# INFO:__main__:Processed Frame 204
# INFO:__main__:Processed Frame 205
# INFO:__main__:Processed Frame 206
# INFO:__main__:Processed Frame 207
# INFO:__main__:Processed Frame 208
# INFO:__main__:Processed Frame 209
# INFO:__main__:Processed Frame 210
# INFO:__main__:Processed Frame 211
# INFO:__main__:Processed Frame 212
# INFO:__main__:Processed Frame 213
# INFO:__main__:Processed Frame 214
# INFO:__main__:Processed Frame 215
# INFO:__main__:Processed Frame 216
# INFO:__main__:Processed Frame 217
# INFO:__main__:Processed Frame 218
# INFO:__main__:Processed Frame 219
# INFO:__main__:Processed Frame 220
# INFO:__main__:Processed Frame 221
# INFO:__main__:Processed Frame 222
# INFO:__main__:Processed Frame 223
# INFO:__main__:Processed Frame 224
# INFO:__main__:Processed Frame 225
# INFO:__main__:Processed Frame 226
# INFO:__main__:Processed Frame 227
# INFO:__main__:Processed Frame 228
# INFO:__main__:Processed Frame 229
# INFO:__main__:Processed Frame 230
# INFO:__main__:Processed Frame 231
# INFO:__main__:Processed Frame 232
# INFO:__main__:Processed Frame 233
# INFO:__main__:Processed Frame 234
# INFO:__main__:Processed Frame 235
# INFO:__main__:Processed Frame 236
# INFO:__main__:Processed Frame 237
# INFO:__main__:Processed Frame 238
# INFO:__main__:Processed Frame 239
# INFO:__main__:Processed Frame 240
# INFO:__main__:Processed Frame 241
# INFO:__main__:Processed Frame 242
# INFO:__main__:Processed Frame 243
# INFO:__main__:Processed Frame 244
# INFO:__main__:Processed Frame 245
# INFO:__main__:Processed Frame 246
# INFO:__main__:Processed Frame 247
# INFO:__main__:Processed Frame 248
# INFO:__main__:Processed Frame 249
# INFO:__main__:Processed Frame 250
# INFO:__main__:Processed Frame 251
# INFO:__main__:Processed Frame 252
# INFO:__main__:Processed Frame 253
# INFO:__main__:Processed Frame 254
# INFO:__main__:Processed Frame 255
# INFO:__main__:Processed Frame 256
# INFO:__main__:Processed Frame 257
# INFO:__main__:Processed Frame 258
# INFO:__main__:Processed Frame 259
# INFO:__main__:Processed Frame 260
# INFO:__main__:Processed Frame 261
# INFO:__main__:Processed Frame 262
# INFO:__main__:Processed Frame 263
# INFO:__main__:Processed Frame 264
# INFO:__main__:Processed Frame 265
# INFO:__main__:Processed Frame 266
# INFO:__main__:Processed Frame 267
# INFO:__main__:Processed Frame 268
# INFO:__main__:Processed Frame 269
# INFO:__main__:Processed Frame 270
# INFO:__main__:Processed Frame 271
# INFO:__main__:Processed Frame 272
# INFO:__main__:Processed Frame 273
# INFO:__main__:Processed Frame 274
# INFO:__main__:Processed Frame 275
# INFO:__main__:Processed Frame 276
# INFO:__main__:Processed Frame 277
# INFO:__main__:Processed Frame 278
# INFO:__main__:Processed Frame 279
# INFO:__main__:Processed Frame 280
# INFO:__main__:Processed Frame 281
# INFO:__main__:Processed Frame 282
# INFO:__main__:Processed Frame 283
# INFO:__main__:Processed Frame 284
# INFO:__main__:Processed Frame 285
# INFO:__main__:Processed Frame 286
# INFO:__main__:Processed Frame 287
# INFO:__main__:Processed Frame 288
# INFO:__main__:Processed Frame 289
# INFO:__main__:Processed Frame 290
# INFO:__main__:Processed Frame 291
# INFO:__main__:Processed Frame 292
# INFO:__main__:Processed Frame 293
# INFO:__main__:Processed Frame 294
# INFO:__main__:Processed Frame 295
# INFO:__main__:Processed Frame 296
# INFO:__main__:Processed Frame 297
# INFO:__main__:Processed Frame 298
# INFO:__main__:Processed Frame 299
# INFO:__main__:Processed Frame 300
# INFO:__main__:Processed Frame 301
# INFO:__main__:Processed Frame 302
# INFO:__main__:Processed Frame 303
# INFO:__main__:Processed Frame 304
# INFO:__main__:Processed Frame 305
# INFO:__main__:Processed Frame 306
# INFO:__main__:Processed Frame 307
# INFO:__main__:Processed Frame 308
# INFO:__main__:Processed Frame 309
# INFO:__main__:Processed Frame 310
# INFO:__main__:Processed Frame 311
# INFO:__main__:Processed Frame 312
# INFO:__main__:Processed Frame 313
# INFO:__main__:Processed Frame 314
# INFO:__main__:Processed Frame 315
# INFO:__main__:Processed Frame 316
# INFO:__main__:Processed Frame 317
# INFO:__main__:Processed Frame 318
# INFO:__main__:Processed Frame 319
# INFO:__main__:Processed Frame 320
# INFO:__main__:Processed Frame 321
# INFO:__main__:Processed Frame 322
# INFO:__main__:Processed Frame 323
# INFO:__main__:Processed Frame 324
# INFO:__main__:Processed Frame 325
# INFO:__main__:Processed Frame 326
# INFO:__main__:Processed Frame 327
# INFO:__main__:Processed Frame 328
# INFO:__main__:Processed Frame 329
# INFO:__main__:Processed Frame 330
# INFO:__main__:Processed Frame 331
# INFO:__main__:Processed Frame 332
# INFO:__main__:Processed Frame 333
# INFO:__main__:Processed Frame 334
# INFO:__main__:Processed Frame 335
# INFO:__main__:Processed Frame 336
# INFO:__main__:Processed Frame 337
# INFO:__main__:Processed Frame 338
# INFO:__main__:Processed Frame 339
# INFO:__main__:Processed Frame 340
# INFO:__main__:Processed Frame 341
# INFO:__main__:Processed Frame 342
# INFO:__main__:Processed Frame 343
# INFO:__main__:Processed Frame 344
# INFO:__main__:Processed Frame 345
# INFO:__main__:Processed Frame 346
# INFO:__main__:Processed Frame 347
# INFO:__main__:Processed Frame 348
# INFO:__main__:Processed Frame 349
# INFO:__main__:Processed Frame 350
# INFO:__main__:Processed Frame 351
# INFO:__main__:Processed Frame 352
# INFO:__main__:Processed Frame 353
# INFO:__main__:Processed Frame 354
# INFO:__main__:Processed Frame 355
# INFO:__main__:Processed Frame 356
# INFO:__main__:Processed Frame 357
# INFO:__main__:Processed Frame 358
# INFO:__main__:Processed Frame 359
# INFO:__main__:Processed Frame 360
# INFO:__main__:Processed Frame 361
# INFO:__main__:Processed Frame 362
# INFO:__main__:Processed Frame 363
# INFO:__main__:Processed Frame 364
# INFO:__main__:Processed Frame 365
# INFO:__main__:Processed Frame 366
# INFO:__main__:Processed Frame 367
# INFO:__main__:Processed Frame 368
# INFO:__main__:Processed Frame 369
# INFO:__main__:Processed Frame 370
# INFO:__main__:Processed Frame 371
# INFO:__main__:Processed Frame 372
# INFO:__main__:Processed Frame 373
# INFO:__main__:Processed Frame 374
# INFO:__main__:Processed Frame 375
# INFO:__main__:Saved tracking results to tracking_results_20250624_144140.json
